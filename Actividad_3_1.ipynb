# %% [markdown]
# <a href="https://colab.research.google.com/github/SaidFlores22/Valores-Atipicos/blob/main/Actividad_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Actividad 3.1 (Valores Atípicos)**
# ## Said Arturo Flores Nieto
# ## A01703477

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e539f1a9-8483-4382-97fe-4316a34d2c89" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e539f1a9-8483-4382-97fe-4316a34d2c89">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

df= pd.read_csv('Ventas_totales_Sin_nulos.csv', index_col = 0)

# %%
df.head()
# Out:
#   indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0    01/01/2017                  27858.900                  27477.300
# 1    01/02/2017                  25994.200                  25223.400
# 2    01/03/2017                  27780.000                  26334.300
# 3    01/04/2017                  29134.300                  27045.900
# 4    01/05/2017                  27969.000                  25631.900
#
#    ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                27858872.080  27591730.130       267141.956
# 1                25994200.170  25749179.400       245020.769
# 2                27780006.520  27472228.720       307777.804
# 3                29134272.220  28827479.490       306792.733
# 4                27969004.680  27569311.410       399693.262
#
#    ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 0               27858872.080 10230100.130      6864575.384       9047205.493
# ...

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65 entries, 0 to 64
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   indice_tiempo                        65 non-null     object
#  1   ventas_precios_corrientes            65 non-null     float64
#  2   ventas_precios_constantes            65 non-null     float64
#  3   ventas_totales_canal_venta           65 non-null     float64
#  4   salon_ventas                         65 non-null     float64
#  5   canales_on_line                      65 non-null     float64
#  6   ventas_totales_medio_pago            65 non-null     float64
#  7   efectivo                             65 non-null     float64
#  8   tarjetas_debito                      65 non-null     float64
#  9   tarjetas_credito                     65 non-null     float64
#  10  otros_medios                         65 non-null     float64
# ...

# %%
df2 = df.drop('indice_tiempo', axis = 1)

fig = plt.figure(figsize =(10, 6))
plt.boxplot(df2) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **1**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["ventas_precios_corrientes"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('ventas_precios_corrientes')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["ventas_precios_corrientes"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["ventas_precios_corrientes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 192319.35000000003
# Limite inferior permitido -59178.650000000016

# %%
#Encontramos Ouliers
outliers_1= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 42    01/07/2020                 211140.700                  50791.400
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 42                81140696.220  76413721.760      4726974.457
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 42               81140696.220 24935747.290     22143208.630      29569224.400
#
#     ...      almacen   panaderia     lacteos      carnes  verduleria_fruteria  \
# 42  ... 23393038.410 2630487.791 9592798.115 8463266.123          2712593.828
#
#     alimentos_preparados_rotiseria  articulos_limpieza_perfumeria  \
# 42                      518942.538                   11217153.190
#
#     indumentaria_calzado_textiles_hogar  electronicos_articulos_hogar  \
# 42                          2502616.619                   6125265.839
#
#          otros
# 42 5935993.913
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_1= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_1["ventas_precios_corrientes"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **2**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["ventas_precios_constantes"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('ventas_precios_constantes')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["ventas_precios_constantes"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["ventas_precios_constantes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 31938.75
# Limite inferior permitido 18759.949999999997

# %%
#Encontramos Ouliers
outliers_2= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 11    01/12/2017                  40766.300                  34084.500
# 42    01/07/2020                 211140.700                  50791.400
# 60    01/01/2022                 154517.100                  45463.400
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 11                40766322.100  40320285.280       446036.825
# 42                81140696.220  76413721.760      4726974.457
# 60               154517094.200 149697614.600      4819479.554
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 11               40766322.100 13710305.370     11070098.740      14576008.240
# 42               81140696.220 24935747.290     22143208.630      29569224.400
# 60              154517094.200 46962602.220     46053650.130      54048333.120
#
#     ...      almacen   panaderia      lacteos       carnes  \
# ...

# %%
#Obtenemos datos limpios
data_clean_2= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 59    01/12/2021                 183983.200                  31595.700
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_2["ventas_precios_constantes"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **3**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["ventas_totales_canal_venta"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('ventas_totales_canal_venta')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["ventas_totales_canal_venta"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["ventas_totales_canal_venta"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 207440738.1500299
# Limite inferior permitido -59963939.482473865

# %%
#Encontramos Ouliers
outliers_3= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_3
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_3= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_3
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_3["ventas_totales_canal_venta"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **4**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["salon_ventas"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('salon_ventas')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["salon_ventas"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["salon_ventas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 170440082.58499998
# Limite inferior permitido -32001350.254999995

# %%
#Encontramos Ouliers
outliers_4= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_4
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                 183983.200                  31595.700
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59               183983151.900 178866721.200      5116430.634
# 63               177148082.800 173003799.100      4144283.743
# 64               179639238.600 175358487.500      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59              183983151.900 56640033.150     55432191.370      62999676.150
# 63              177148082.800 53189998.680     50063972.790      65357591.090
# 64              179639238.600 52738110.620     49886787.860      68070088.230
#
#     ...      almacen   panaderia      lacteos       carnes  \
# ...

# %%
#Obtenemos datos limpios
data_clean_4= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_4
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 57    01/10/2021                 140487.500                  25386.700
# 58    01/11/2021                 141702.000                  25026.600
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_4["salon_ventas"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **5**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["canales_on_line"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('canales_on_line')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["canales_on_line"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["canales_on_line"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 7623053.091870596
# Limite inferior permitido -3467249.0753690572

# %%
#Encontramos Ouliers
outliers_5= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_5
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_5= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_5
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_5["canales_on_line"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **6**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["ventas_totales_medio_pago"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('ventas_totales_medio_pago')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["ventas_totales_medio_pago"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["ventas_totales_medio_pago"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 205953106.93160364
# Limite inferior permitido -57477046.72544977

# %%
#Encontramos Ouliers
outliers_6= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_6
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_6= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_6
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_6["ventas_totales_medio_pago"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **7**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["efectivo"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('efectivo')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["efectivo"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["efectivo"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 61911595.63423146
# Limite inferior permitido -14342695.590508386

# %%
#Encontramos Ouliers
outliers_7= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_7
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_7= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_7
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_7["efectivo"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **8**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["tarjetas_debito"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('tarjetas_debito')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["tarjetas_debito"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["tarjetas_debito"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 51933510.0585
# Limite inferior permitido -15937937.1375

# %%
#Encontramos Ouliers
outliers_8= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_8
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                 183983.200                  31595.700
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59               183983151.900 178866721.200      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59              183983151.900 56640033.150     55432191.370      62999676.150
#
#     ...      almacen   panaderia      lacteos       carnes  \
# 59  ... 45199914.720 5859939.041 16275221.460 21265049.450
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                   21753939.730                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                  12669269.760 16665123.150
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_8= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_8
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_8["tarjetas_debito"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **9**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["tarjetas_credito"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('tarjetas_credito')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["tarjetas_credito"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["tarjetas_credito"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 66191782.864999995
# Limite inferior permitido -18528673.494999994

# %%
#Encontramos Ouliers
outliers_9= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_9
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 64               179639238.600 175358487.500      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 64              179639238.600 52738110.620     49886787.860      68070088.230
#
#     ...      almacen   panaderia      lacteos       carnes  \
# 64  ... 50150351.460 6667329.665 20121124.430 22841532.850
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64          6314109.470                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                   23578638.710                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                  12039595.550 12349980.060
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_9= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_9
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 59    01/12/2021                 183983.200                  31595.700
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_9["tarjetas_credito"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **10**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["otros_medios"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('otros_medios')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["otros_medios"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["otros_medios"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 10753828.419683132
# Limite inferior permitido -3714075.237190824

# %%
#Encontramos Ouliers
outliers_10= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_10
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_10= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_10
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_10["otros_medios"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **11**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["ventas_totales_grupo_articulos"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('ventas_totales_grupo_articulos')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["ventas_totales_grupo_articulos"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["ventas_totales_grupo_articulos"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 205953106.93160364
# Limite inferior permitido -57477046.72544977

# %%
#Encontramos Ouliers
outliers_11= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_11
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_11= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_11
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_11["ventas_totales_grupo_articulos"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **12**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["subtotal_ventas_alimentos_bebidas"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('subtotal_ventas_alimentos_bebidas')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["subtotal_ventas_alimentos_bebidas"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["subtotal_ventas_alimentos_bebidas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 114548006.925
# Limite inferior permitido -11790048.954999998

# %%
#Encontramos Ouliers
outliers_12= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_12
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                 183983.200                  31595.700
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59               183983151.900 178866721.200      5116430.634
# 62               168982502.300 164321107.300       466134.998
# 63               177148082.800 173003799.100      4144283.743
# 64               179639238.600 175358487.500      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59              183983151.900 56640033.150     55432191.370      62999676.150
# 62              168982502.300 51262080.990     47364363.880      53705893.170
# ...

# %%
#Obtenemos datos limpios
data_clean_12= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_12
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 56    01/09/2021                 123002.300                  22962.000
# 57    01/10/2021                 140487.500                  25386.700
# 58    01/11/2021                 141702.000                  25026.600
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_12["subtotal_ventas_alimentos_bebidas"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **13**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["bebidas"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('bebidas')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["bebidas"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["bebidas"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 26469391.430539995
# Limite inferior permitido -8774655.518293843

# %%
#Encontramos Ouliers
outliers_13= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_13
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                 183983.200                  31595.700
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59               183983151.900 178866721.200      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59              183983151.900 56640033.150     55432191.370      62999676.150
#
#     ...      almacen   panaderia      lacteos       carnes  \
# 59  ... 45199914.720 5859939.041 16275221.460 21265049.450
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                   21753939.730                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                  12669269.760 16665123.150
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_13= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_13
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_13["bebidas"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **14**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["almacen"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('almacen')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["almacen"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["almacen"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 54985691.28381896
# Limite inferior permitido -14998070.155480493

# %%
#Encontramos Ouliers
outliers_14= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_14
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_14= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_14
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_14["almacen"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **15**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["panaderia"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('panaderia')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["panaderia"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["panaderia"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 5314390.465
# Limite inferior permitido -928804.111

# %%
#Encontramos Ouliers
outliers_15= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_15
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                 183983.200                  31595.700
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59               183983151.900 178866721.200      5116430.634
# 62               168982502.300 164321107.300       466134.998
# 63               177148082.800 173003799.100      4144283.743
# 64               179639238.600 175358487.500      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59              183983151.900 56640033.150     55432191.370      62999676.150
# 62              168982502.300 51262080.990     47364363.880      53705893.170
# ...

# %%
#Obtenemos datos limpios
data_clean_15= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_15
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 56    01/09/2021                 123002.300                  22962.000
# 57    01/10/2021                 140487.500                  25386.700
# 58    01/11/2021                 141702.000                  25026.600
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_15["panaderia"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **16**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["lacteos"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('lacteos')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["lacteos"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["lacteos"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 19940661.0455
# Limite inferior permitido -5569362.3025

# %%
#Encontramos Ouliers
outliers_16= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_16
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 64               179639238.600 175358487.500      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 64              179639238.600 52738110.620     49886787.860      68070088.230
#
#     ...      almacen   panaderia      lacteos       carnes  \
# 64  ... 50150351.460 6667329.665 20121124.430 22841532.850
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64          6314109.470                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                   23578638.710                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                  12039595.550 12349980.060
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_16= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_16
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 59    01/12/2021                 183983.200                  31595.700
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_16["lacteos"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **17**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["carnes"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('carnes')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["carnes"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["carnes"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 25080072.045855798
# Limite inferior permitido -8445963.450871184

# %%
#Encontramos Ouliers
outliers_17= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_17
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_17= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_17
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_17["carnes"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **18**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["verduleria_fruteria"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('verduleria_fruteria')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["verduleria_fruteria"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["verduleria_fruteria"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 7566284.623383936
# Limite inferior permitido -2300308.6422116277

# %%
#Encontramos Ouliers
outliers_18= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_18
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_18= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_18
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_18["verduleria_fruteria"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **19**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["alimentos_preparados_rotiseria"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('alimentos_preparados_rotiseria')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["alimentos_preparados_rotiseria"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["alimentos_preparados_rotiseria"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 1546751.13875
# Limite inferior permitido -227313.79444999993

# %%
#Encontramos Ouliers
outliers_19= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_19
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                 183983.200                  31595.700
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59               183983151.900 178866721.200      5116430.634
# 62               168982502.300 164321107.300       466134.998
# 63               177148082.800 173003799.100      4144283.743
# 64               179639238.600 175358487.500      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59              183983151.900 56640033.150     55432191.370      62999676.150
# 62              168982502.300 51262080.990     47364363.880      53705893.170
# ...

# %%
#Obtenemos datos limpios
data_clean_19= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_19
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 56    01/09/2021                 123002.300                  22962.000
# 57    01/10/2021                 140487.500                  25386.700
# 58    01/11/2021                 141702.000                  25026.600
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_19["alimentos_preparados_rotiseria"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **20**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["articulos_limpieza_perfumeria"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('articulos_limpieza_perfumeria')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["articulos_limpieza_perfumeria"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["articulos_limpieza_perfumeria"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 26933276.02311951
# Limite inferior permitido -6271196.185704121

# %%
#Encontramos Ouliers
outliers_20= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_20
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_20= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_20
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_20["articulos_limpieza_perfumeria"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **21**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["indumentaria_calzado_textiles_hogar"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('indumentaria_calzado_textiles_hogar')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["indumentaria_calzado_textiles_hogar"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["indumentaria_calzado_textiles_hogar"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 4001205.6905000005
# Limite inferior permitido -784042.9135000001

# %%
#Encontramos Ouliers
outliers_21= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_21
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 54    01/07/2021                 125658.600                  24779.500
# 59    01/12/2021                 183983.200                  31595.700
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 54               125658552.500 120904098.300      4754454.215
# 59               183983151.900 178866721.200      5116430.634
# 63               177148082.800 173003799.100      4144283.743
# 64               179639238.600 175358487.500      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 54              125658552.500 37973547.560     37146178.900      43727330.440
# 59              183983151.900 56640033.150     55432191.370      62999676.150
# ...

# %%
#Obtenemos datos limpios
data_clean_21= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_21
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 57    01/10/2021                 140487.500                  25386.700
# 58    01/11/2021                 141702.000                  25026.600
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_21["indumentaria_calzado_textiles_hogar"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **22**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["electronicos_articulos_hogar"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('electronicos_articulos_hogar')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["electronicos_articulos_hogar"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["electronicos_articulos_hogar"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 11851594.895499999
# Limite inferior permitido -3640353.060499999

# %%
#Encontramos Ouliers
outliers_22= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_22
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 58    01/11/2021                 141702.000                  25026.600
# 59    01/12/2021                 183983.200                  31595.700
# 60    01/01/2022                 154517.100                  45463.400
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 58               141701960.700 135950778.800      5751181.809
# 59               183983151.900 178866721.200      5116430.634
# 60               154517094.200 149697614.600      4819479.554
# 64               179639238.600 175358487.500      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 58              141701960.700 43762928.150     39925207.450      50752243.390
# 59              183983151.900 56640033.150     55432191.370      62999676.150
# ...

# %%
#Obtenemos datos limpios
data_clean_22= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_22
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 56    01/09/2021                 123002.300                  22962.000
# 57    01/10/2021                 140487.500                  25386.700
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_22["electronicos_articulos_hogar"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **23**

# %%
df.columns
# Out:
# Index(['indice_tiempo', 'ventas_precios_corrientes',
#        'ventas_precios_constantes', 'ventas_totales_canal_venta',
#        'salon_ventas', 'canales_on_line', 'ventas_totales_medio_pago',
#        'efectivo', 'tarjetas_debito', 'tarjetas_credito', 'otros_medios',
#        'ventas_totales_grupo_articulos', 'subtotal_ventas_alimentos_bebidas',
#        'bebidas', 'almacen', 'panaderia', 'lacteos', 'carnes',
#        'verduleria_fruteria', 'alimentos_preparados_rotiseria',
#        'articulos_limpieza_perfumeria', 'indumentaria_calzado_textiles_hogar',
#        'electronicos_articulos_hogar', 'otros'],
#       dtype='object')

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["otros"], color='blue', rwidth=0.50)
plt.title('Histograma')
plt.xlabel('otros')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["otros"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["otros"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 15400188.083717234
# Limite inferior permitido -3988638.8826710805

# %%
#Encontramos Ouliers
outliers_23= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers_23
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                 183983.200                  31595.700
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59               183983151.900 178866721.200      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59              183983151.900 56640033.150     55432191.370      62999676.150
#
#     ...      almacen   panaderia      lacteos       carnes  \
# 59  ... 45199914.720 5859939.041 16275221.460 21265049.450
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                   21753939.730                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                  12669269.760 16665123.150
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_23= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean_23
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                  27858.900                  27477.300
# 1     01/02/2017                  25994.200                  25223.400
# 2     01/03/2017                  27780.000                  26334.300
# 3     01/04/2017                  29134.300                  27045.900
# 4     01/05/2017                  27969.000                  25631.900
# ..           ...                        ...                        ...
# 60    01/01/2022                 154517.100                  45463.400
# 61    01/02/2022                 152202.600                  23802.100
# 62    01/03/2022                     16.500                  24612.400
# 63    01/04/2022                 177148.100                  24140.500
# 64    01/05/2022                 179639.200                  23234.200
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_23["otros"]) 
plt.title("Outliers")
plt.show() #dibujamos el diagrama

# %%
from google.colab import files 

data_clean_1.to_csv("ventas_precios_corrientes sin atipicos.csv")
data_clean_2.to_csv("ventas_precios_constantes sin atipicos.csv")
data_clean_4.to_csv("salon_ventas sin atipicos.csv")
data_clean_8.to_csv("tarjetas_debito sin atipicos.csv")
data_clean_9.to_csv("tarjetas_credito sin atipicos.csv")
data_clean_12.to_csv("subtotal_ventas_alimentos_bebidas sin atipicos.csv")
data_clean_13.to_csv("bebidas sin atipicos.csv")
data_clean_15.to_csv("panaderia sin atipicos.csv")
data_clean_16.to_csv("lacteos sin atipicos.csv")
data_clean_19.to_csv("alimentos_preparados_rotiseria sin atipicos.csv")
data_clean_21.to_csv("indumentaria_calzado_textiles_hogar sin atipicos.csv")
data_clean_22.to_csv("electronicos_articulos_hogar sin atipicos.csv")
data_clean_23.to_csv("otros sin atipicos.csv")

# %%
files.download("ventas_precios_corrientes sin atipicos.csv")
files.download("ventas_precios_constantes sin atipicos.csv")
files.download("salon_ventas sin atipicos.csv")
files.download("tarjetas_debito sin atipicos.csv")
files.download("tarjetas_credito sin atipicos.csv")
files.download("subtotal_ventas_alimentos_bebidas sin atipicos.csv")
files.download("bebidas sin atipicos.csv")
files.download("panaderia sin atipicos.csv")
files.download("lacteos sin atipicos.csv")
files.download("alimentos_preparados_rotiseria sin atipicos.csv")
files.download("indumentaria_calzado_textiles_hogar sin atipicos.csv")
files.download("electronicos_articulos_hogar sin atipicos.csv")
files.download("otros sin atipicos.csv")
